# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.54  Python-3.11.8 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Setup complete  (16 CPUs, 15.7 GB RAM, 191.5/466.2 GB disk)

# %%
import os
import zipfile

# %%
with zipfile.ZipFile('test_image_dir.zip') as target_file:
    target_file.extractall('test_image_dir')

# %%
content_path='test_image_dir'

# %%
from PIL import Image
from IPython.display import Image
image1 = Image(filename=content_path+'/test_image_dir/test1.jpg')
display(image1)

# %%
image2= Image(filename=content_path+'/test_image_dir/test2.jpg')
display(image2)

# %%
image3= Image(filename=content_path+'/test_image_dir/test3.jpg')
display(image3)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt') # MicroSoft coco dataset으로 pre-trained 모델

# %%
# model class 확인

print(model.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
# 경로에 있는 jpg 파일을 results에 저장

results = model.predict(source=content_path+'/test_image_dir/*.jpg', save=True)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/5 c:\Users\USER\Desktop\HS\GitHub\YOLO_examples\test_image_dir\test_image_dir\bts.jpg: 384x640 7 persons, 4 chairs, 123.1ms
# image 2/5 c:\Users\USER\Desktop\HS\GitHub\YOLO_examples\test_image_dir\test_image_dir\test1.jpg: 544x640 1 laptop, 1 mouse, 2 keyboards, 1 cell phone, 105.0ms
# image 3/5 c:\Users\USER\Desktop\HS\GitHub\YOLO_examples\test_image_dir\test_image_dir\test2.jpg: 448x640 4 zebras, 1 giraffe, 98.0ms
# image 4/5 c:\Users\USER\Desktop\HS\GitHub\YOLO_examples\test_image_dir\test_image_dir\test3.jpg: 640x640 2 cups, 1 bowl, 2 sandwichs, 1 dining table, 7.0ms
# image 5/5 c:\Users\USER\Desktop\HS\GitHub\YOLO_examples\test_image_dir\test_image_dir\test4.jpg: 480x640 2 persons, 1 truck, 1 horse, 96.0ms
# Speed: 2.6ms preprocess, 85.8ms inference, 17.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict3
